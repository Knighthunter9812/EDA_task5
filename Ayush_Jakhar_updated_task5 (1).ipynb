# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('C:\\Users\\ayush\\OneDrive\\Desktop\\pizza_v2.csv')

# %%
df.head()
# Out:
#   company price_rupiah diameter      topping           variant     size  \
# 0       A    Rp235,000  22 inch      chicken  double_signature    jumbo
# 1       A    Rp198,000  20 inch    papperoni  double_signature    jumbo
# 2       A    Rp120,000  16 inch    mushrooms  double_signature  reguler
# 3       A    Rp155,000  14 inch  smoked_beef  double_signature  reguler
# 4       A    Rp248,000  18 inch   mozzarella  double_signature    jumbo
#
#   extra_sauce extra_cheese extra_mushrooms
# 0         yes          yes              no
# 1         yes          yes              no
# 2         yes          yes             yes
# 3         yes           no             yes
# 4         yes           no             yes

# %%
df['company'].unique()
# Out:
# array(['A', 'B', 'C', 'D', 'E'], dtype=object)

# %%
df['diameter'].unique()
# Out:
# array(['22 inch', '20 inch', '16 inch', '14 inch', '18 inch', '18.5 inch',
#        '8 inch', '12 inch', '16.5 inch', '8.5 inch', '17 inch',
#        '14 inch\n'], dtype=object)

# %%
# df1 = df.sort_values(by=['diameter'],ascending=False)

# %%
# df1.head()

# %%
# df1=df.sort_values(by='diameter',ascending=False)
# df1.head()

# %%
# df1.tail()
# df.isnull().any()

# %% [markdown]
# ## Types of topping according to size

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='diameter',y='topping',data=df)
# Out:
# <Axes: xlabel='diameter', ylabel='topping'>

# %%
df['size'].unique()
#sns.heatmap(df.corr(),annot=True)
# Out:
# array(['jumbo', 'reguler', 'small', 'medium', 'large', 'XL'], dtype=object)

# %% [markdown]
# ## most preffered diameter is  12inch

# %%
sns.countplot(x=df['diameter'])
# Out:
# <Axes: xlabel='diameter', ylabel='count'>

# %% [markdown]
# ## Diffferent company's preffered diameter

# %%
sns.scatterplot(x='company',y='diameter',data=df)
# Out:
# <Axes: xlabel='company', ylabel='diameter'>

# %%
df['diameter'] = df['diameter'].astype(str)
df['price_rupiah'] = df['price_rupiah'].astype(str)
df['diameter']=df['diameter'].str.replace('inch','').astype(float)
df['price_rupiah'] = df['price_rupiah'].str.replace('Rp', '').str.replace(',', '').astype(int)
df
# Out:
#     company  price_rupiah  diameter      topping           variant     size  \
# 0         A        235000      22.0      chicken  double_signature    jumbo
# 1         A        198000      20.0    papperoni  double_signature    jumbo
# 2         A        120000      16.0    mushrooms  double_signature  reguler
# 3         A        155000      14.0  smoked_beef  double_signature  reguler
# 4         A        248000      18.0   mozzarella  double_signature    jumbo
# ..      ...           ...       ...          ...               ...      ...
# 124       E         39000       8.5         tuna        spicy tuna    small
# 125       E         72000      12.0         tuna        spicy tuna   medium
# 126       E         99000      14.0         tuna        spicy tuna    large
# 127       E         44000       8.5         meat   BBQ_meat_fiesta    small
# 128       E         78000      12.0         meat   BBQ_meat_fiesta   medium
#
#     extra_sauce extra_cheese extra_mushrooms
# ...

# %% [markdown]
# ## price of pizza accrding to diameter

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x='price_rupiah',y='diameter',data=df)
# Out:
# <Axes: xlabel='price_rupiah', ylabel='diameter'>

# %% [markdown]
# ### different topping price that is papperoni is most expensive

# %%
plt.figure(figsize=(18,6))
sns.barplot(y='price_rupiah',x='topping',data=df)
# Out:
# <Axes: xlabel='topping', ylabel='price_rupiah'>

# %% [markdown]
# ### price and topping combined with sauce implies if sauce is not taken then black_papper is most expensive

# %%
plt.figure(figsize=(18,6))
sns.barplot(y='price_rupiah',x='topping',data=df,hue='extra_sauce')
# Out:
# <Axes: xlabel='topping', ylabel='price_rupiah'>

# %% [markdown]
# ### if cheese is taken black_pepper most expensive else papperoni most expensive

# %%
plt.figure(figsize=(18,6))
sns.barplot(y='price_rupiah',x='topping',data=df,hue='extra_cheese')
# Out:
# <Axes: xlabel='topping', ylabel='price_rupiah'>

# %% [markdown]
# ### if extra mushroom there then black_pepper most expensive else papperoine most expansive

# %%
plt.figure(figsize=(18,6))
sns.barplot(y='price_rupiah',x='topping',data=df,hue='extra_mushrooms')
# Out:
# <Axes: xlabel='topping', ylabel='price_rupiah'>

# %% [markdown]
# ## price with respect to size and topping

# %%
plt.figure(figsize=(18,6))
sns.barplot(y='price_rupiah',x='size',data=df,hue='topping')
# Out:
# <Axes: xlabel='size', ylabel='price_rupiah'>

# %% [markdown]
# ##  Toppings available in different size

# %%
sns.scatterplot(y='topping',x='size',data=df)
# Out:
# <Axes: xlabel='size', ylabel='topping'>

# %%
#In this medium and large size is more expensive without extra sauce then with regular sauce 
sns.barplot(y='price_rupiah',x='size',data=df,hue='extra_sauce')
# Out:
# <Axes: xlabel='size', ylabel='price_rupiah'>

# %%
plt.figure(figsize=(30,10))
sns.lineplot(y='price_rupiah',x='variant',data=df)
# Out:
# <Axes: xlabel='variant', ylabel='price_rupiah'>

# %% [markdown]
# ## company with highest order

# %%
df.describe()
sns.barplot(x='company',y='price_rupiah',data=df)
# Out:
# <Axes: xlabel='company', ylabel='price_rupiah'>

# %% [markdown]
# #### As company A,D contribute most in the profit which focus more on expensive variant which include double_signature,double_mix,double_decker

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='company',y='variant',data=df)
# Out:
# <Axes: xlabel='company', ylabel='variant'>

# %%
sns.histplot(df['extra_sauce'])
# Out:
# <Axes: xlabel='extra_sauce', ylabel='Count'>

# %%
sns.histplot(df['extra_sauce'])
# Out:
# <Axes: xlabel='extra_sauce', ylabel='Count'>

# %%
sns.histplot(df['extra_mushrooms'])
# Out:
# <Axes: xlabel='extra_mushrooms', ylabel='Count'>

# %% [markdown]
# ## most preferred diameter company wise

# %%
plt.figure(figsize=(18,8))
sns.countplot(x=df['company'],hue=df['diameter'])
# Out:
# <Axes: xlabel='company', ylabel='count'>

# %% [markdown]
# ## chicken is most preffered topping

# %%
plt.figure(figsize=(18,6))
sns.countplot(x=df['topping'])
# Out:
# <Axes: xlabel='topping', ylabel='count'>
